# %%
import lxw

# %% [markdown]
# ### 1、排序

# %%
client = lxw.new_client()
messages = [
    {
        "role": "user",
        "content": """
你是一名小红书的典型年轻女性用户。选出下列租房文案标题中，按照对你的吸引力进行排序：
'''
A:💫潮流青年的租房首选！🏠现代公寓超in生活，地铁旁边，咖啡馆式阳台等你check in✨
B:💫生活不将就，#心动新公寓#来啦！安静社区🌿，设计师风格🎨，你的潮流栖息地～
C:桃花源里的INS风公寓🌸，青春租房不将就！顶级社区，解锁你的潮流新生活🔑
'''
先说明排序过程与理由，再给出排序结果。
        """
    }
]
response = client.chat.completions.create(
    model = lxw.gpt4_turbo,
    messages = messages,
    n=3
)
lxw.print_response(response)
# Out:
# --------1--------
#
# 根据小红书年轻女性用户的兴趣倾向，比较偏爱时尚潮流、设计感强、社区品质高，同时对于社交媒体元素（如INS风）和生活品质（如不将就、心动新公寓）也较为敏感。基于这些考虑，我们可以进行如下排序：
#
# 首先，我们考虑到年轻女性用户可能较为偏好接近流行文化和社交媒体趋势的标签。标题C提到了“桃花源里的INS风公寓”，这可能触发她们对于梦幻、文艺感以及热门网络风格的兴趣。“INS风”（即Instagram风）能够引起用户将这种公寓与流行、社交媒体热点联系起来。此外，“顶级社区”也说明了社区的高品质，而“青春租房不将就”则讲述了对生活品质的坚持。
#
# 其次，标题A提到了多种吸引年轻人的元素：“潮流青年的租房首选”，“咖啡馆式阳台”，以及“地铁旁边”，这些信息既满足了对现代便利生活的想象，又带有一定的社交和生活方式场景。特别是位置上的优势（地铁旁边）也是年轻用户考虑的重点之一。
#
# 最后，标题B虽然也很吸引人，但相比之下缺少了一些特定的地理位置优势，例如“地铁旁边”，也没有使用社交媒体元素，但它的优势在于强调了“设计师风格”和“安静社区”，这些都是年轻用户在寻找品质生活时可能会很在意的方面。
#
# 综上所述，标题的排序如下：
# 1. 标题C：桃花源里的INS风公寓🌸，青春租房不将就！顶级社区，解锁你的潮流新生活🔑
# 2. 标题A：💫潮流青年的租房首选！🏠现代公寓超in生活，地铁旁边，咖啡馆式阳台等你check in✨
# 3. 标题B：💫生活不将就，#心动新公寓#来啦！安静社区🌿，设计师风格🎨，你的潮流栖息地～
#
#
# --------2--------
#
# 作为一名小红书的典型年轻女性用户，可能会对时尚元素、潮流生活方式、便捷的地理位置以及独特的居住体验等因素较为敏感。而小红书平台本身就充满了讲究生活品质、追求时尚趋势的气息，因此租房文案标题中涵盖这些内容的会更加吸引这类用户。
#
# 在判断这三个选项时，可以考虑以下几点：
# - 社区环境和位置：包含交通便利、社区品质。
# - 设计风格和生活方式：是否有特殊的设计元素，是否符合年轻潮人的品味。
# - 生活品质的体现：是否提供了与众不同的生活体验或者可以提升生活品质的设施。
# - 文案吸引力：使用的语言和符号是否能引起情感共鸣，符号如💫、🌸、🏠等也会造成影响。
#
# 据此分析，排序如下：
#
# 1. A:💫潮流青年的租房首选！🏠现代公寓超in生活，地铁旁边，咖啡馆式阳台等你check in✨
# 理由：这则文案明确提到了“潮流青年”的概念，符合用户身份定位。同时，提及了“现代公寓超in生活”和“咖啡馆式阳台”，这些都传达了时尚和高品质生活感，附加的“地铁旁边”强调了地理位置的便利性。
#
# 2. B:💫生活不将就，#心动新公寓#来啦！安静社区🌿，设计师风格🎨，你的潮流栖息地～
# 理由：包含了“生活不将就”和“设计师风格”的描述，符合追求品质和个性化的生活态度。此外，“安静社区”和“潮流栖息地”暗示了一个舒适且有品味的居住环境。
#
# 3. C:桃花源里的INS风公寓🌸，青春租房不将就！顶级社区，解锁你的潮流新生活🔑
# 理由：这则文案侧重于优质的居住环境（“桃花源里”，“顶级社区”），而且有“INS风”这个流行元素，对年轻用户有一定吸引力。不过，与前两个选项相比，缺少了一些对地理位置和生活便利性的具体描述，因此排在第三位。
#
#
# --------3--------
#
# 作为一名小红书的年轻女性用户，我更倾向于选择那些能够契合我的生活方式、喜好和审美的租房文案。以下是我的排序理由：
#
# 1. 对年轻用户来说，“潮流”和“现代”是两个很重要的关键词，这代表着公寓和生活方式都很符合当下的时尚趋势。旁边有地铁说明交通便利，而“咖啡馆式阳台”预示了一个可以享受悠闲时光的场所。
#
# 2. “桃花源”“INS风”可以吸引喜欢拍照和分享生活的用户，而“青春租房不将就”和“解锁你的潮流新生活”说明这个公寓可能与年轻人的生活理念和追求紧密相连。
#
# 3. “生活不将就”反映了现代年轻人追求高品质生活态度，“心动新公寓”描绘了一个值得期待的画面。同时，“安静社区”和“设计师风格”传达了一个倾向于品质和专业设计的居住空间。
#
# 综合以上考虑，我的排序如下：
# A: 潮流青年的租房首选！现代公寓超in生活，地铁旁边，咖啡馆式阳台等你check in✨
# C: 桃花源里的INS风公寓，青春租房不将就！顶级社区，解锁你的潮流新生活🔑
# B: 生活不将就，#心动新公寓#来啦！安静社区，设计师风格，你的潮流栖息地～
#
# 这个排序把交通便利、时尚生活方式和社交/分享元素看做是吸引年轻女性用户关注的重要因素。

# %% [markdown]
# ### 2、改变次序

# %%
client = lxw.new_client()
messages = [
    {
        "role": "user",
        "content": """
你是一名小红书的典型年轻女性用户。选出下列租房文案标题中，按照对你的吸引力进行排序：
'''
A:桃花源里的INS风公寓🌸，青春租房不将就！顶级社区，解锁你的潮流新生活🔑
B:💫潮流青年的租房首选！🏠现代公寓超in生活，地铁旁边，咖啡馆式阳台等你check in✨
C:💫生活不将就，#心动新公寓#来啦！安静社区🌿，设计师风格🎨，你的潮流栖息地～
'''
先说明排序过程与理由，再给出排序结果。
        """
    }
]
response = client.chat.completions.create(
    model = lxw.gpt4_turbo,
    messages = messages,
    n=3
)
lxw.print_response(response)
# Out:
# --------1--------
#
# 排序过程首先会根据典型小红书年轻女性用户的兴趣进行假设。小红书用户通常对时尚、设计感、社交媒体的分享元素和生活品质有较高的重视。基于此，以下是标题的排序理由：
#
# 1. 标题A暗示了INS（Instagram）风格，这通常与时尚、美观和社交媒体分享的元素联系在一起，符合小红书用户群体的喜好；同时，'桃花源里'暗示了一种理想化、有逃离日常感的氛围，'青春租房不将就'与'解锁你的潮流新生活'的措辞强调了生活品质和个性化的追求。
#
# 2. 标题B有'潮流青年'这一明确定位，'地铁旁边'表明了便捷性，'咖啡馆式阳台'则是让人联想到休闲和社交的场所，很适合拍照分享到社交媒体，'超in生活'也符合潮流感。
#
# 3. 标题C同样强调了生活品质（'生活不将就'），并且提到了'心动新公寓'和'设计师风格'，这些都是吸引年轻女性用户的元素。不过，相较于A和B标题，C标题缺少了一些具体的、可以激发用户想象的描述，例如地段、周边环境的特点等。
#
# 综上所述，按照对典型小红书年轻女性用户的吸引力排序为：
# A > B > C
#
#
# --------2--------
#
# 作为一名小红书的年轻女性用户，我可能会受到以下几个因素的影响：
#
# 1. 时尚元素：标题中涉及时尚、潮流、设计感相关的词汇，如“INS风”、“潮流”、“设计师风格”等，将提高我对文章的兴趣。
#
# 2. 生活品质：提到“顶级社区”、“安静社区”、“地铁旁边”等，这些都暗示着生活质量可能较高，这同样会吸引我。
#
# 3. 想象空间：“桃花源里”、“阳台”等具体的描绘可以激发我想要了解详情的好奇心。
#
# 4. 使用标签和emoji符号：小红书用户通常喜欢丰富的视觉元素，例如emoji和流行标签。
#
# 据此，我会将它们排序如下：
#
# A: "桃花源里的INS风公寓🌸，青春租房不将就！顶级社区，解锁你的潮流新生活🔑"
# 这个标题用词有趣且富有想象力（“桃花源里”的INS风公寓很吸引人），还提到了“顶级社区”、“潮流新生活”，强调了时尚和生活品质。
#
# B: "💫潮流青年的租房首选！🏠现代公寓超in生活，地铁旁边，咖啡馆式阳台等你check in✨"
# 这个标题对"潮流青年"有很强烈的吸引力，并且提到了"现代公寓"、"地铁旁边"和有趣的"咖啡馆式阳台"。
#
# C: "💫生活不将就，#心动新公寓#来啦！安静社区🌿，设计师风格🎨，你的潮流栖息地～"
# 虽然也很吸引人，但是这个标题不如其他两个突出，关键词“设计师风格”虽然是一个吸引点，但没有提供一些像“桃花源”或“阳台”这样的具体想象图景。
#
# 所以，按从最吸引力到最少的排序是：A > B > C。
#
#
# --------3--------
#
# 作为一名小红书的典型年轻女性用户，我的关注点可能会集中在以下几个方面：设计感和风格、社区环境、便利设施，以及是否符合年轻的潮流审美。在社交平台上，我也可能更倾向于那些听起来能够提供有趣和美观拍摄背景的地方。
#
# 现在我们来看每个选项的特点：
#
# A选项的亮点是"桃花源里的INS风公寓"和"顶级社区"，这两点可能会给我带来一个远离喧嚣、高品质且具备良好摄影场景的印象。"解锁你的潮流新生活"给人感觉租住这里可以提升自己的生活品质，符合年轻人对时尚生活的追求。
#
# B选项的亮点在于"潮流青年的租房首选"和"超in生活"，它强调了现代化和青年文化，并且提到了地铁旁边和咖啡馆式阳台，这可能表示它地理位置优越，且有一个好的自然拍照地点。
#
# C选项的亮点包含"不将就"、"心动新公寓"、"安静社区"和"设计师风格"。这个标题突出了对精致生活的追求和对设计品质的重视，可能更吸引追求独特个性与风格的用户。
#
# 根据上面的分析，我的排序如下：
#
# 1. A选项: 它结合了潮流与高品质的社区环境，还有INS风这一对年轻女性用户具有很大吸引力的关键词，可能更容易吸引我的注意力。
# 2. C选项: 作为对品质和设计有要求的用户，"设计师风格"和"不将就"这样的描述可能会使我觉得这个公寓能够满足我对生活品质的追求。
# 3. B选项: 虽然这个选项也提到了潮流和地段优势，但与A、C选项相比，它对风格和社区环境的描述不如另外两个选项突出，因此我可能会把它放在最后一位。
#
# 排序结果：A > C > B
